# %% [markdown]
# <a href="https://colab.research.google.com/github/SuryaBhaskar33/LGMVIPTASKS/blob/main/LGMTASK4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Name - Kanduri Surya Bhaskar**
# ## LetsGrowMore-VIP
# ## September-2021
# ##Domain- Data Science Intern

# %% [markdown]
# ## **Exploratory Data Analysis of global terrorism**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv("/content/GT.csv",encoding='latin-1')
data.head()
# Out:
#         eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0  197000000001   1970       7     2  ...      0.0       0.0     0.0      NaN
# 1  197000000002   1970       0     0  ...      1.0       1.0     1.0      NaN
# 2  197001000001   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 3  197001000002   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 4  197001000003   1970       1     0  ...     -9.0       1.0     1.0      NaN
#
# [5 rows x 135 columns]

# %%
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
data.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
#        'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2',
#        'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed',
#        'claimmode', 'claimmode_txt', 'claim2', 'claimmode2',
#        'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt',
#        'compclaim', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2',
#        'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3',
#        'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4',
#        'weapsubtype4_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid',
#        'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert',
#        'kidhijcountry', 'ransom', 'ransomamt', 'ransomamtus',
#        'ransompaid', 'ransompaidus', 'ransomnote', 'hostkidoutcome',
#        'hostkidoutcome_txt', 'nreleased', 'addnotes', 'scite1', 'scite2',
#        'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY',
#        'related'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83305 entries, 0 to 83304
# Columns: 135 entries, eventid to related
# dtypes: float64(61), int64(16), object(58)
# memory usage: 85.8+ MB

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0  197000000001   1970       7     2  ...      0.0       0.0     0.0      NaN
# 1  197000000002   1970       0     0  ...      1.0       1.0     1.0      NaN
# 2  197001000001   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 3  197001000002   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 4  197001000003   1970       1     0  ...     -9.0       1.0     1.0      NaN
#
# [5 rows x 135 columns]

# %%
data.tail()
# Out:
#             eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 83300  200706050033   2007       6     5  ...     -9.0       0.0    -9.0      NaN
# 83301  200706050034   2007       6     5  ...     -9.0       0.0    -9.0      NaN
# 83302  200706050035   2007       6     5  ...      0.0       0.0     0.0      NaN
# 83303  200706050036   2007       6     5  ...      0.0       0.0     0.0      NaN
# 83304  200706050037   2007       6     5  ...      NaN       NaN     NaN      NaN
#
# [5 rows x 135 columns]

# %%
data.corr()
# Out:
#             eventid     iyear    imonth  ...  INT_IDEO  INT_MISC   INT_ANY
# eventid    1.000000  0.999990 -0.031328  ... -0.159839 -0.076059 -0.171124
# iyear      0.999990  1.000000 -0.035258  ... -0.159818 -0.076040 -0.171079
# imonth    -0.031328 -0.035258  1.000000  ... -0.003172 -0.001903 -0.008843
# iday      -0.010677 -0.010779  0.004344  ... -0.002866  0.000731  0.000364
# extended   0.071778  0.071767 -0.001525  ...  0.032227  0.036737  0.049458
# ...             ...       ...       ...  ...       ...       ...       ...
# nreleased -0.318131 -0.318049 -0.012026  ...  0.013667  0.075957  0.054859
# INT_LOG   -0.161967 -0.161945 -0.003681  ...  0.994519  0.055414  0.844684
# INT_IDEO  -0.159839 -0.159818 -0.003172  ...  1.000000  0.095703  0.848637
# INT_MISC  -0.076059 -0.076040 -0.001903  ...  0.095703  1.000000  0.274893
# INT_ANY   -0.171124 -0.171079 -0.008843  ...  0.848637  0.274893  1.000000
#
# [77 rows x 77 columns]

# %%
data.describe()
# Out:
#             eventid         iyear  ...      INT_MISC       INT_ANY
# count  8.330500e+04  83305.000000  ...  83304.000000  83304.000000
# mean   1.989953e+11   1989.887774  ...      0.123199     -3.139417
# std    8.649329e+08      8.650362  ...      0.768035      4.564757
# min    1.970000e+11   1970.000000  ...     -9.000000     -9.000000
# 25%    1.984013e+11   1984.000000  ...      0.000000     -9.000000
# 50%    1.990031e+11   1990.000000  ...      0.000000      0.000000
# 75%    1.996053e+11   1996.000000  ...      0.000000      0.000000
# max    2.007061e+11   2007.000000  ...      1.000000      1.000000
#
# [8 rows x 77 columns]

# %%
data.rename(columns={'iyear':'Year','imonth':'Month','iday':"day",'gname':'Group','country_txt':'Country','region_txt':'Region','provstate':'State','city':'City','latitude':'latitude',
    'longitude':'longitude','summary':'summary','attacktype1_txt':'Attacktype','targtype1_txt':'Targettype','weaptype1_txt':'Weapon','nkill':'kill',
     'nwound':'Wound'},inplace=True)

# %%
data = data[['Year','Month','day','Country','State','Region','City','latitude','longitude',"Attacktype",'kill',
               'Wound','target1','summary','Group','Targettype','Weapon','motive']]

# %%
data.shape
# Out:
# (83305, 18)

# %%
data.isnull().sum()
# Out:
# Year              0
# Month             0
# day               0
# Country           0
# State           418
# Region            0
# City             66
# latitude       3939
# longitude      3940
# Attacktype        0
# kill           6389
# Wound          9367
# target1         511
# summary       66129
# Group             1
# Targettype        1
# Weapon            1
# motive        66559
# dtype: int64

# %%
data['kill']=data['kill'].fillna(0)
data['Wound']=data['Wound'].fillna(0)

# %%
data['Casualities'] = data['kill']+ data['Wound']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83305 entries, 0 to 83304
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         83305 non-null  int64
#  1   Month        83305 non-null  int64
#  2   day          83305 non-null  int64
#  3   Country      83305 non-null  object
#  4   State        82887 non-null  object
#  5   Region       83305 non-null  object
#  6   City         83239 non-null  object
#  7   latitude     79366 non-null  float64
#  8   longitude    79365 non-null  float64
#  9   Attacktype   83305 non-null  object
#  10  kill         83305 non-null  float64
#  11  Wound        83305 non-null  float64
#  12  target1      82794 non-null  object
#  13  summary      17176 non-null  object
#  14  Group        83304 non-null  object
#  15  Targettype   83304 non-null  object
#  16  Weapon       83304 non-null  object
#  17  motive       16746 non-null  object
#  18  Casualities  83305 non-null  float64
# dtypes: float64(5), int64(3), object(11)
# memory usage: 12.1+ MB

# %%
year = data['Year'].unique()
years_count = data['Year'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (15,10))
sns.barplot(x = year, y = years_count, palette = 'tab10')
plt.xticks(rotation = 45)
plt.xlabel('Attacking Year',fontsize=20)
plt.ylabel('Number of Attacks Each Year',Fontsize=20)
plt.title('Attacks In Years',fontsize=22)
plt.show()

# %%
df = data[['Year','kill']].groupby(['Year']).sum()
fig, ax4 = plt.subplots(figsize=(20,10))
df.plot(kind='bar',alpha=0.8,ax=ax4)
plt.xticks(rotation = 50)
plt.title("People Died By Attack",fontsize=25)
plt.ylabel("Number of people killed",fontsize=20)
plt.xlabel('Year',fontsize=20)
top_side = ax4.spines["top"]
top_side.set_visible(False)
right_side = ax4.spines["right"]
right_side.set_visible(False)

# %%
data['City'].value_counts().to_frame().sort_values('City',axis=0,ascending=False).head(10).plot(kind='bar',figsize=(10,10))
plt.xticks(rotation = 50)
plt.xlabel("City",fontsize=10)
plt.ylabel("Number of attack",fontsize=10)
plt.title("Top 10 most effected city",fontsize=10)
plt.show()

# %%
data['Attacktype'].value_counts().plot(kind='bar',figsize=(10,10),color='BROWN')
## plt.xticks(rotation = 50)
plt.xlabel("TYPE OF ATTACK",fontsize=10)
plt.ylabel("NUMBER OF ATTACK",fontsize=20)
plt.title("NAME OF TYPE OF ATTACK",fontsize=20)
plt.show()

# %%
data[['Attacktype','kill']].groupby(["Attacktype"],axis=0).sum().plot(kind='bar',figsize=(20,10))
plt.xticks(rotation=50)
plt.title("Number of killed ",fontsize=20)
plt.ylabel('Number of people',fontsize=15)
plt.xlabel('Attack type',fontsize=15)
plt.show()

# %%
pd.crosstab(data.Year, data.Region).plot(kind='area',stacked=False,figsize=(20,10))
plt.title('Terrorist Activities By Region In Each Year',fontsize=25)
plt.ylabel('Number of Attacks',fontsize=20)
plt.xlabel("Year",fontsize=20)
plt.show()

# %%
attack = data.Country.value_counts()[:10]
attack
# Out:
# Colombia          6927
# Peru              6039
# El Salvador       5320
# United Kingdom    4424
# India             4317
# Spain             3162
# Sri Lanka         2723
# Turkey            2689
# United States     2541
# Philippines       2472
# Name: Country, dtype: int64

# %%
plt.subplots(figsize=(20,10))
sns.barplot(data['Country'].value_counts()[:10].index,data['Country'].value_counts()[:10].values)
plt.title('Top Countries Affected')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation = 50)
plt.show()

# %%
data[['Group','kill']].groupby(['Group'],axis=0).sum().drop('Unknown').sort_values('kill',ascending=False).head(10).plot(kind='bar',figsize=(10,10))
plt.title("Top 10 terrorist group attack",fontsize=20)
plt.xlabel("terrorist group name",fontsize=15)
plt.ylabel("No of killed people",fontsize=15)
plt.show()

# %%
kill = data.loc[:,'kill']
print('Number of people killed by terror attack:', int(sum(kill.dropna())))
# Out:
# Number of people killed by terror attack: 187955

# %%
df = data.pivot_table(columns='Attacktype', values='kill', aggfunc='sum')

df
# Out:
# Attacktype  Armed Assault  Assassination  ...  Unarmed Assault  Unknown
# kill              93678.0        17673.0  ...            655.0  13040.0
#
# [1 rows x 10 columns]

# %%
df1 = data.pivot_table(columns='Country', values='kill', aggfunc='sum')
df1
# Out:
# Country  Afghanistan  Albania  Algeria  ...  Zaire  Zambia  Zimbabwe
# kill          2559.0     41.0  10135.0  ...  324.0    70.0     145.0
#
# [1 rows x 203 columns]

# %%
df=data[['Group','Country','kill']]
df=df.groupby(['Group','Country'],axis=0).sum().sort_values('kill',ascending=False).drop('Unknown').reset_index().head(5)
df
# Out:
#                                               Group      Country     kill
# 0                                 Shining Path (SL)         Peru  11533.0
# 1           Liberation Tigers of Tamil Eelam (LTTE)    Sri Lanka  10340.0
# 2  Farabundo Marti National Liberation Front (FMLN)  El Salvador   8019.0
# 3                 Nicaraguan Democratic Force (FDN)    Nicaragua   6630.0
# 4     Revolutionary Armed Forces of Colombia (FARC)     Colombia   4988.0

# %%
#top 10 countries with most number of attacks
attack = data.Country.value_counts()[:10]
attack
# Out:
# Colombia          6927
# Peru              6039
# El Salvador       5320
# United Kingdom    4424
# India             4317
# Spain             3162
# Sri Lanka         2723
# Turkey            2689
# United States     2541
# Philippines       2472
# Name: Country, dtype: int64

# %%
#top 10 terrorist groups with most number of attacks
data.Group.value_counts()[1:11]
# Out:
# Shining Path (SL)                                   4512
# Farabundo Marti National Liberation Front (FMLN)    3351
# Irish Republican Army (IRA)                         2669
# Basque Fatherland and Freedom (ETA)                 1968
# Revolutionary Armed Forces of Colombia (FARC)       1632
# Liberation Tigers of Tamil Eelam (LTTE)             1453
# National Liberation Army of Colombia (ELN)          1266
# Kurdistan Workers' Party (PKK)                      1139
# Palestinians                                        1125
# New People's Army (NPA)                             1082
# Name: Group, dtype: int64
